# %%
import pandas as pd
df = pd.read_csv("Fraud_check (2).csv")
df
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# ...

# %%
df.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
df.tail()
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO

# %%
df.dtypes
# Out:
# Undergrad          object
# Marital.Status     object
# Taxable.Income      int64
# City.Population     int64
# Work.Experience     int64
# Urban              object
# dtype: object

# %%
a = df.columns
a
# Out:
# Index(['Undergrad', 'Marital.Status', 'Taxable.Income', 'City.Population',
#        'Work.Experience', 'Urban'],
#       dtype='object')

# %%
df.isna()
# Out:
#      Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0        False           False           False            False
# 1        False           False           False            False
# 2        False           False           False            False
# 3        False           False           False            False
# 4        False           False           False            False
# ..         ...             ...             ...              ...
# 595      False           False           False            False
# 596      False           False           False            False
# 597      False           False           False            False
# 598      False           False           False            False
# 599      False           False           False            False
#
#      Work.Experience  Urban
# 0              False  False
# 1              False  False
# 2              False  False
# 3              False  False
# 4              False  False
# ...

# %%
df.isna().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
for i in a:
    if (df[i].dtypes)!="O":
        sns.distplot(df[i])
        plt.figure()

# %%
sns.set_style(style="darkgrid")
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()
df['Undergrad']=Le.fit_transform(df['Undergrad'])
df['Marital.Status']=Le.fit_transform(df['Marital.Status'])
df['Urban']=Le.fit_transform(df['Urban'])

# %%
TaxableIncome_cat= []
for i in range(0,600):
    if df["Taxable.Income"][i] <= 30000:
       TaxableIncome_cat.append("Risky")
    else: 
       TaxableIncome_cat.append("Good")

# %%
df1 = pd.DataFrame({"TI":TaxableIncome_cat})
df1
# Out:
#        TI
# 0    Good
# 1    Good
# 2    Good
# 3    Good
# 4    Good
# ..    ...
# 595  Good
# 596  Good
# 597  Good
# 598  Good
# 599  Good
#
# [600 rows x 1 columns]

# %%
df1=pd.concat([df,df1], axis=1)
df1
# Out:
#      Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0            0               2           68833            50047
# 1            1               0           33700           134075
# 2            0               1           36925           160205
# 3            1               2           50190           193264
# 4            0               1           81002            27533
# ..         ...             ...             ...              ...
# 595          1               0           76340            39492
# 596          1               0           69967            55369
# 597          0               0           47334           154058
# 598          1               1           98592           180083
# 599          0               0           96519           158137
#
#      Work.Experience  Urban    TI
# 0                 10      1  Good
# 1                 18      1  Good
# 2                 30      1  Good
# 3                 15      1  Good
# ...

# %%
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()
df1["TI"] = Le.fit_transform(df1["TI"])
df1
# Out:
#      Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0            0               2           68833            50047
# 1            1               0           33700           134075
# 2            0               1           36925           160205
# 3            1               2           50190           193264
# 4            0               1           81002            27533
# ..         ...             ...             ...              ...
# 595          1               0           76340            39492
# 596          1               0           69967            55369
# 597          0               0           47334           154058
# 598          1               1           98592           180083
# 599          0               0           96519           158137
#
#      Work.Experience  Urban  TI
# 0                 10      1   0
# 1                 18      1   0
# 2                 30      1   0
# 3                 15      1   0
# ...

# %%
df1.columns
# Out:
# Index(['Undergrad', 'Marital.Status', 'Taxable.Income', 'City.Population',
#        'Work.Experience', 'Urban', 'TI'],
#       dtype='object')

# %%
X1=df1[['Undergrad', 'Marital.Status', 'City.Population','Work.Experience', 'Urban',]]
X1
# Out:
#      Undergrad  Marital.Status  City.Population  Work.Experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
# [600 rows x 5 columns]

# %%
Y1=df1["TI"]
Y1.value_counts()
# Out:
# 0    476
# 1    124
# Name: TI, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_count  = SS.fit_transform(X1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
train_acc=[]
test_acc=[]
for i in range(1,700):
    X_train,X_test,Y_train,Y_test = train_test_split(SS_count,Y1, test_size=0.30)

    RFC = RandomForestClassifier(max_samples= 0.6, 
                        n_estimators = 100, 
                        max_features = 0.6, random_state=24,max_depth=4)
    RFC.fit(X_train,Y_train)

    Y_Pred_train = RFC.predict(X_train)
    Y_Pred_test = RFC.predict(X_test)
    train_acc.append(accuracy_score(Y_train,Y_Pred_train).round(2))
    test_acc.append( accuracy_score(Y_test,Y_Pred_test).round(2))

print('Training accuracy', np.mean(train_acc))
print('Test accuracy', np.mean(test_acc))
# Out:
# Training accuracy 0.7965808297567953
# Test accuracy 0.7926609442060085
